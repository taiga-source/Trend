# %% [markdown]
# 整理　画像サイズ、モデルを構築するところ

# %%
import cv2
import pandas as pd
import os

def list_image_paths(directory):
    """ディレクトリ内の画像ファイルのパスをリスト化する関数"""
    from pathlib import Path
    image_files = list(Path(directory).glob("*.[jp][np]*[g]"))  # jpg, jpeg, png
    return [(i, str(image_file)) for i, image_file in enumerate(image_files)]

# DataFrameを初期化
df = pd.DataFrame(columns=['index', 'width', 'height', 'channels'])

def load_image(image_path):
    """画像を読み込んでRGB形式で返す"""
    img_bgr = cv2.imread(image_path)
    if img_bgr is None:
        return None
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    return img_rgb

def img_size(index):
    """画像のサイズを取得する関数"""
    # 画像が入っているディレクトリのパス
    img_pss = '/content/drive/MyDrive/PythonProjects/トレンド予測/服の検出/imgs/デザイナーズ'

    # 画像パスのリストを取得
    image_paths = list_image_paths(img_pss)

    if index >= len(image_paths):
        return None

    image_path = image_paths[index][1]
    image = load_image(image_path)

    if image is None:
        return None

    height, width, channels = image.shape
    return {'index': index, 'width': width, 'height': height, 'channels': channels}

# サイズ情報をDataFrameに追加
image_paths = list_image_paths('/content/drive/MyDrive/PythonProjects/トレンド予測/服の検出/imgs/デザイナーズ')

size_list = []
for i in range(len(image_paths)):
    size_info = img_size(i)
    if size_info:
        size_list.append(size_info)

df = pd.DataFrame(size_list)

print(df)

import pandas as pd

# 既存のDataFrame df がある前提で、サイズが225x225の行を抽出
df_filtered = df[(df['width'] == 225) & (df['height'] == 225)]

print(df_filtered)

def list_image_paths(directory):
    """指定したディレクトリ内の画像ファイルのパスを番号付きでリストする関数"""
    # ディレクトリ内の全てのファイルを取得
    files = os.listdir(directory)

    # 画像ファイルの拡張子リスト
    image_extensions = {'.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff'}

    # 画像ファイルのパスを番号付きでリストする
    image_paths = []
    for idx, file in enumerate(files):
        # 拡張子を確認
        if os.path.splitext(file)[1].lower() in image_extensions:
            image_path = os.path.join(directory, file)
            image_paths.append((idx + 1, image_path))

    return image_paths

# 画像が入っているディレクトリのパス
img_pss = '/content/drive/MyDrive/PythonProjects/トレンド予測/服の検出/imgs/デザイナーズ'

# 画像パスのリストを取得
image_paths = list_image_paths(img_pss)

"""指定したディレクトリ内の画像ファイルのパスを番号付きでリストする関数"""
directory = '/content/drive/MyDrive/PythonProjects/トレンド予測/服の検出/imgs/デザイナーズ'
# ディレクトリ内の全てのファイルを取得
files = os.listdir(directory)
print(files)

# 画像ファイルの拡張子リスト
image_extensions = {'.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff'}

# 画像ファイルのパスを番号付きでリストする
image_paths = []
for idx, file in enumerate(files):
    # 拡張子を確認
    if os.path.splitext(file)[1].lower() in image_extensions:
        image_path = os.path.join(directory, file)
        image_paths.append((idx + 1, image_path))

import re

# ファイル名のリスト
file_names = ['8.jpg', '2.jpg', '1.jpg', '7.jpg', '5.jpg', '4.jpg', '3.jpg']

# ファイル名から数字部分を抽出してソートする関数
def extract_number(file_name):
    match = re.search(r'\d+', file_name)
    if match:
        return int(match.group())
    return 0

# ソート
sorted_file_names = sorted(file_names, key=extract_number)

print(sorted_file_names)

# ファイル名から数字部分を抽出してソートする関数
def extract_number(file_name):
    match = re.search(r'\d+', file_name)
    if match:
        return int(match.group())
    return 0



def list_image_paths(directory):
    """指定したディレクトリ内の画像ファイルのパスを番号付きでリストする関数"""
    # ディレクトリ内の全てのファイルを取得
    files = os.listdir(directory)

    # ソート
    files = sorted(files, key=extract_number)
    print(files)

    # 画像ファイルの拡張子リスト
    image_extensions = {'.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff'}

    # 画像ファイルのパスを番号付きでリストする
    image_paths = []
    for idx, file in enumerate(files):
        # 拡張子を確認
        if os.path.splitext(file)[1].lower() in image_extensions:
            image_path = os.path.join(directory, file)
            image_paths.append((idx + 1, image_path))

    return image_paths

# 画像が入っているディレクトリのパス
img_pss = '/content/drive/MyDrive/PythonProjects/トレンド予測/服の検出/imgs/デザイナーズ'

# 画像パスのリストを取得
image_paths = list_image_paths(img_pss)

import cv2
import pandas as pd

# ファイル名から数字部分を抽出してソートする関数
def extract_number(file_name):
    match = re.search(r'\d+', file_name)
    if match:
        return int(match.group())
    return 0



def list_image_paths(directory):
    """指定したディレクトリ内の画像ファイルのパスを番号付きでリストする関数"""
    # ディレクトリ内の全てのファイルを取得
    files = os.listdir(directory)

    # ソート
    files = sorted(files, key=extract_number)

    # 画像ファイルの拡張子リスト
    image_extensions = {'.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff'}

    # 画像ファイルのパスを番号付きでリストする
    image_paths = []
    for idx, file in enumerate(files):
        # 拡張子を確認
        if os.path.splitext(file)[1].lower() in image_extensions:
            image_path = os.path.join(directory, file)
            image_paths.append((idx + 1, image_path))

    return image_paths

# 画像が入っているディレクトリのパス
img_pss = '/content/drive/MyDrive/PythonProjects/トレンド予測/服の検出/imgs/デザイナーズ'

# 画像パスのリストを取得
image_paths = list_image_paths(img_pss)


# DataFrameを初期化
df = pd.DataFrame(columns=['index', 'width', 'height', 'channels'])

def load_image(image_path):
    """画像を読み込んでRGB形式で返す"""
    img_bgr = cv2.imread(image_path)
    if img_bgr is None:
        return None
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    return img_rgb

def img_size(index):
    """画像のサイズを取得する関数"""
    # 画像が入っているディレクトリのパス
    img_pss = '/content/drive/MyDrive/PythonProjects/トレンド予測/服の検出/imgs/デザイナーズ'

    # 画像パスのリストを取得
    image_paths = list_image_paths(img_pss)

    if index >= len(image_paths):
        return None

    image_path = image_paths[index][1]
    image = load_image(image_path)

    if image is None:
        return None

    height, width, channels = image.shape
    return {'index': index, 'width': width, 'height': height, 'channels': channels}

# サイズ情報をDataFrameに追加
image_paths = list_image_paths('/content/drive/MyDrive/PythonProjects/トレンド予測/服の検出/imgs/デザイナーズ')

size_list = []
for i in range(len(image_paths)):
    size_info = img_size(i)
    if size_info:
        size_list.append(size_info)

df = pd.DataFrame(size_list)

print(df)

import cv2
import os
import re
import pandas as pd

# ファイル名から数字部分を抽出してソートする関数
def extract_number(file_name):
    match = re.search(r'\d+', file_name)
    if match:
        return int(match.group())
    return 0

def list_image_paths(directory):
    """指定したディレクトリ内の画像ファイルのパスを番号付きでリストする関数"""
    # ディレクトリ内の全てのファイルを取得
    files = os.listdir(directory)

    # ソート
    files = sorted(files, key=extract_number)
    print(files)

    # 画像ファイルの拡張子リスト
    image_extensions = {'.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff'}

    # 画像ファイルのパスを番号付きでリストする
    image_paths = []
    for idx, file in enumerate(files):
        # 拡張子を確認
        if os.path.splitext(file)[1].lower() in image_extensions:
            image_path = os.path.join(directory, file)
            image_paths.append((idx + 1, image_path))

    return image_paths

# 画像が入っているディレクトリのパス
img_pss = '/content/drive/MyDrive/PythonProjects/トレンド予測/服の検出/imgs/デザイナーズ'

# 画像パスのリストを取得
image_paths = list_image_paths(img_pss)

# DataFrameを初期化
df = pd.DataFrame(columns=['index', 'width', 'height', 'channels'])

def load_image(image_path):
    """画像を読み込んでRGB形式で返す"""
    img_bgr = cv2.imread(image_path)
    if img_bgr is None:
        return None
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    return img_rgb

def img_size(index):
    """画像のサイズを取得する関数"""
    if index >= len(image_paths):
        return None

    image_path = image_paths[index][1]
    image = load_image(image_path)

    if image is None:
        return None

    height, width, channels = image.shape
    return {'index': index, 'width': width, 'height': height, 'channels': channels}

# サイズ情報をDataFrameに追加
size_list = []
for i in range(len(image_paths)):
    size_info = img_size(i)
    if size_info:
        size_list.append(size_info)

df = pd.DataFrame(size_list)
import pandas as pd

# 既存のDataFrame df がある前提で、サイズが225x225の行を抽出
df_filtered = df[(df['width'] == 225) & (df['height'] == 225)]

print(df_filtered)
path = image_paths[12][1]

# Get the file name
file_name = os.path.basename(path)
print(file_name)
def img_size(index):
    """画像のサイズを取得する関数"""
    if index >= len(image_paths):
        return None

    image_path = image_paths[index][1]
    image = load_image(image_path)

    path = image_paths[12][1]

    # Get the file name
    file_name = os.path.basename(path)

    if image is None:
        return None

    height, width, channels = image.shape
    return {'file_name': file_name, 'width': width, 'height': height, 'channels': channels}

img_size(1)
img_pss = '/content/drive/MyDrive/PythonProjects/トレンド予測/服の検出/imgs/デザイナーズ'

import cv2
import os
import re
import pandas as pd

# ファイル名から数字部分を抽出してソートする関数
def extract_number(file_name):
    match = re.search(r'\d+', file_name)
    if match:
        return int(match.group())
    return 0

def list_image_paths(directory):
    """指定したディレクトリ内の画像ファイルのパスを番号付きでリストする関数"""
    # ディレクトリ内の全てのファイルを取得
    files = os.listdir(directory)

    # ソート
    files = sorted(files, key=extract_number)
    print(files)

    # 画像ファイルの拡張子リスト
    image_extensions = {'.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff'}

    # 画像ファイルのパスを番号付きでリストする
    image_paths = []
    for idx, file in enumerate(files):
        # 拡張子を確認
        if os.path.splitext(file)[1].lower() in image_extensions:
            image_path = os.path.join(directory, file)
            image_paths.append((idx + 1, image_path))

    return image_paths

# 画像が入っているディレクトリのパス
img_pss = '/content/drive/MyDrive/PythonProjects/トレンド予測/服の検出/imgs/デザイナーズ'

# 画像パスのリストを取得
image_paths = list_image_paths(img_pss)

# DataFrameを初期化
df = pd.DataFrame(columns=['index', 'width', 'height', 'channels'])

def load_image(image_path):
    """画像を読み込んでRGB形式で返す"""
    img_bgr = cv2.imread(image_path)
    if img_bgr is None:
        return None
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    return img_rgb

def img_size(index):
    """画像のサイズを取得する関数"""
    if index >= len(image_paths):
        return None

    image_path = image_paths[index][1]
    image = load_image(image_path)

    path = image_paths[index][1]

    # Get the file name
    file_name = os.path.basename(path)

    if image is None:
        return None

    height, width, channels = image.shape
    return {'index':index, 'file_name': file_name, 'width': width, 'height': height, 'channels': channels}

# サイズ情報をDataFrameに追加
size_list = []
for i in range(len(image_paths)):
    size_info = img_size(i)
    if size_info:
        size_list.append(size_info)

df = pd.DataFrame(size_list)
import pandas as pd

# 既存のDataFrame df がある前提で、サイズが225x225の行を抽出
df_filtered = df[(df['width'] == 225) & (df['height'] == 225)]

print(df_filtered)
casual_styles = [
    "ベーシック",
    "アメリカンカジュアル（アメカジ）",
    "モードカジュアル",
    "スポーツカジュアル",
    "ストリートカジュアル",
    "アウトドア"
]

elegant_styles = [
    "エレガンス",
    "ガーリー",
    "オフィスカジュアル",
    "キャリア",
    "マニッシュ",
    "デザイナーズ"
]

other_styles = [
    "トラッド",
    "ノームコア",
    "ナチュラル",
    "韓国（オルチャン）",
    "量産型",
    "地雷系"
]

sum_list = casual_styles + elegant_styles + other_styles
sum_list

import cv2
import os
import re
import pandas as pd

# ファイル名から数字部分を抽出してソートする関数
def extract_number(file_name):
    match = re.search(r'\d+', file_name)
    if match:
        return int(match.group())
    return 0

def list_image_paths(directory):
    """指定したディレクトリ内の画像ファイルのパスを番号付きでリストする関数"""
    # ディレクトリ内の全てのファイルを取得
    files = os.listdir(directory)

    # ソート
    files = sorted(files, key=extract_number)
    print(files)

    # 画像ファイルの拡張子リスト
    image_extensions = {'.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff'}

    # 画像ファイルのパスを番号付きでリストする
    image_paths = []
    for idx, file in enumerate(files):
        # 拡張子を確認
        if os.path.splitext(file)[1].lower() in image_extensions:
            image_path = os.path.join(directory, file)
            image_paths.append((idx + 1, image_path))

    return image_paths

def load_image(image_path):
    """画像を読み込んでRGB形式で返す"""
    img_bgr = cv2.imread(image_path)
    if img_bgr is None:
        return None
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    return img_rgb

def img_size(index, query, image_paths):
    """画像のサイズを取得する関数"""
    if index >= len(image_paths):
        return None

    image_path = image_paths[index][1]
    image = load_image(image_path)

    path = image_paths[index][1]

    # Get the file name
    file_name = os.path.basename(path)

    if image is None:
        return None

    height, width, channels = image.shape
    return {'index':index, 'ancestry': query, 'file_name': file_name, 'width': width, 'height': height, 'channels': channels}

def ancestry(query):
  # 画像が入っているディレクトリのパス
  img_pss = '/content/drive/MyDrive/PythonProjects/トレンド予測/服の検出/imgs/{}'.format(query)

  # 画像パスのリストを取得
  image_paths = list_image_paths(img_pss)

  # DataFrameを初期化
  df = pd.DataFrame(columns=['index', 'width', 'height', 'channels'])

  # サイズ情報をDataFrameに追加
  size_list = []
  for i in range(len(image_paths)):
      size_info = img_size(i, query, image_paths)
      if size_info:
          size_list.append(size_info)

  df = pd.DataFrame(size_list)

  # 既存のDataFrame df がある前提で、サイズが225x225の行を抽出
  df_filtered = df[(df['width'] == 225) & (df['height'] == 225)]

  print(df_filtered)

  return df_filtered

print(ancestry(sum_list[0]))

import cv2
import os
import re
import pandas as pd
from tqdm import tqdm

# ファイル名から数字部分を抽出してソートする関数
def extract_number(file_name):
    match = re.search(r'\d+', file_name)
    if match:
        return int(match.group())
    return 0

def list_image_paths(directory):
    """指定したディレクトリ内の画像ファイルのパスを番号付きでリストする関数"""
    # ディレクトリ内の全てのファイルを取得
    files = os.listdir(directory)

    # ソート
    files = sorted(files, key=extract_number)

    # 画像ファイルの拡張子リスト
    image_extensions = {'.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff'}

    # 画像ファイルのパスを番号付きでリストする
    image_paths = []
    for idx, file in enumerate(files):
        # 拡張子を確認
        if os.path.splitext(file)[1].lower() in image_extensions:
            image_path = os.path.join(directory, file)
            image_paths.append((idx + 1, image_path))

    return image_paths

def load_image(image_path):
    """画像を読み込んでRGB形式で返す"""
    img_bgr = cv2.imread(image_path)
    if img_bgr is None:
        return None
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    return img_rgb

def img_size(index, query, image_paths):
    """画像のサイズを取得する関数"""
    if index >= len(image_paths):
        return None

    image_path = image_paths[index][1]
    image = load_image(image_path)

    path = image_paths[index][1]

    # Get the file name
    file_name = os.path.basename(path)

    if image is None:
        return None

    height, width, channels = image.shape
    return {'index': index, 'ancestry': query, 'file_name': file_name, 'width': width, 'height': height, 'channels': channels}

def ancestry(query):
    # 画像が入っているディレクトリのパス
    img_pss = '/content/drive/MyDrive/PythonProjects/トレンド予測/服の検出/imgs/{}'.format(query)

    # 画像パスのリストを取得
    image_paths = list_image_paths(img_pss)

    # DataFrameを初期化
    df = pd.DataFrame(columns=['index', 'ancestry', 'file_name', 'width', 'height', 'channels'])

    # サイズ情報をDataFrameに追加
    size_list = []
    for i in range(len(image_paths)):
        size_info = img_size(i, query, image_paths)
        if size_info:
            size_list.append(size_info)

    df = pd.DataFrame(size_list)

    # 既存のDataFrame df がある前提で、サイズが225x225の行を抽出
    df_filtered = df[(df['width'] == 225) & (df['height'] == 225)]

    return df_filtered


list_df = []

# Example list
example_list = range(len(sum_list))

# Using tqdm to show the progress bar
for item in tqdm(example_list):
    list_df.append(ancestry(sum_list[item]))

# Display the first dataframe in the list
print(list_df[0])
# Out:
#      index  width  height  channels
# 0        0     46      65         3
# 1        1     70      46         3
# 2        2     69      46         3
# 3        3     46      47         3
# 4        4     61      46         3
# ..     ...    ...     ...       ...
# 987    988     16      16         3
# 988    989    225     225         3
# 989    990     16      16         3
# 990    991    225     225         3
# 991    992     16      16         3
#
# [992 rows x 4 columns]
#      index  width  height  channels
# 10      10    225     225         3
# 12      12    225     225         3
# 14      14    225     225         3
# 15      15    225     225         3
# 16      16    225     225         3
# ..     ...    ...     ...       ...
# 982    983    225     225         3
# 983    984    225     225         3
# 986    987    225     225         3
# 988    989    225     225         3
# 990    991    225     225         3
#
# [495 rows x 4 columns]
# ...

# %%
import cv2
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

def load_and_preprocess_images(base_path, label, num):
    """画像を読み込み、ラベルを付ける"""
    data = []
    img_dir = base_path  # base_pathを使用
    file_names = list_df[num]['file_name']  # 各ファイル名のリストを取得

    for file_name in file_names:
        img_path = os.path.join(img_dir, file_name)  # OSに依存しないファイルパス作成
        img = cv2.imread(img_path)
        if img is None:
            print(f"画像が読み込めませんでした: {img_path}")
            continue
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # BGRからRGBに変換
        data.append((img_rgb, label))  # 修正: 画像全体とラベルを対応付ける

    return data

def data_info(df):
    """データフレームからラベルとベースパスを取得"""
    label = df['ancestry'].unique()[0]
    print(label)
    base_path = '/content/drive/MyDrive/PythonProjects/トレンド予測/服の検出/imgs/{}'.format(label)
    return label, base_path

# ラベルと画像パスのリストを作成
list_labels = []
list_paths = []
for i in range(len(sum_list)):
    label, base_path = data_info(list_df[i])
    list_labels.append(label)
    list_paths.append(base_path)

# データの読み込みと前処理
list_data2 = []
for i, style in enumerate(sum_list):
    if i >= len(list_paths) or i >= len(list_labels):
        print(f"インデックス {i} が list_paths または list_labels の範囲外です")
        continue
    data = load_and_preprocess_images(list_paths[i], list_labels[i], i)
    list_data2.append(data)

# データを特徴量とラベルに分ける例
# データフレームに変換する場合
X = []
y = []

for data in list_data2:
    for img, label in data:
        X.append(img)
        y.append(label)

X = np.array(X)
y = np.array([list_labels.index(lbl) for lbl in y])
#y = to_categorical(y, num_classes=len(list_labels))

# データの確認
print(f"データの数: {len(X)}")
print(f"画像の形状: {X[0].shape}")
print(f"正解ラベル: {y[0]}")

import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
from torch import optim

# データセットのカスタムクラス
class ImageDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

# データとラベルの確認
print(f"データの数: {len(X)}")
print(f"画像の形状: {X[0].shape}")
print(f"正解ラベル: {y[0]}")



import cv2
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# 系統名のリスト
style_names = [
    'ベーシック',
    'アメリカンカジュアル（アメカジ）',
    'モードカジュアル',
    'スポーツカジュアル',
    'ストリートカジュアル',
    'アウトドア',
    'エレガンス',
    'ガーリー',
    'オフィスカジュアル',
    'キャリア',
    'マニッシュ',
    'デザイナーズ',
    'トラッド',
    'ノームコア',
    'ナチュラル',
    '韓国（オルチャン）',
    '量産型',
    '地雷系'
]

def load_and_preprocess_images(base_path, label, num):
    """画像を読み込み、ラベルを付ける"""
    data = []
    img_dir = base_path  # base_pathを使用
    file_names = list_df[num]['file_name']  # 各ファイル名のリストを取得

    for file_name in file_names:
        img_path = os.path.join(img_dir, file_name)  # OSに依存しないファイルパス作成
        img = cv2.imread(img_path)
        if img is None:
            print(f"画像が読み込めませんでした: {img_path}")
            continue
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # BGRからRGBに変換
        data.append((img_rgb, label))  # 修正: 画像全体とラベルを対応付ける

    return data

def data_info(df):
    """データフレームからラベルとベースパスを取得"""
    label = df['ancestry'].unique()[0]
    base_path = '/content/drive/MyDrive/PythonProjects/トレンド予測/服の検出/imgs/{}'.format(label)
    return label, base_path

# ラベルと画像パスのリストを作成
list_labels = []
list_paths = []
for i in range(len(sum_list)):
    label, base_path = data_info(list_df[i])
    list_labels.append(label)
    list_paths.append(base_path)

# データの読み込みと前処理
list_data2 = []
for i, style in enumerate(sum_list):
    if i >= len(list_paths) or i >= len(list_labels):
        print(f"インデックス {i} が list_paths または list_labels の範囲外です")
        continue
    data = load_and_preprocess_images(list_paths[i], list_labels[i], i)
    list_data2.append(data)

# データを特徴量とラベルに分ける例
# データフレームに変換する場合
X = []
y = []

for data in list_data2:
    for img, label in data:
        X.append(img)
        y.append(label)

X = np.array(X)

# 系統名を数値に変換するための辞書を作成
label_to_index = {name: idx for idx, name in enumerate(style_names)}

# ラベルを数値から系統名に変換
y = np.array([label_to_index[lbl] for lbl in y])

# 数値ラベルを系統名に変換
y_names = [style_names[idx] for idx in y]

# データの確認
print(f"データの数: {len(X)}")
print(f"画像の形状: {X[0].shape}")
print(f"正解ラベル: {y_names[0]}")
# Out:
# ベーシック
# アメリカンカジュアル（アメカジ）
# モードカジュアル
# スポーツカジュアル
# ストリートカジュアル
# アウトドア
# エレガンス
# ガーリー
# オフィスカジュアル
# キャリア
# マニッシュ
# デザイナーズ
# トラッド
# ノームコア
# ナチュラル
# 韓国（オルチャン）
# 量産型
# 地雷系
# データの数: 6250
# 画像の形状: (225, 225, 3)
# 正解ラベル: 0
# データの数: 6250
# 画像の形状: (225, 225, 3)
# 正解ラベル: 0
# データの数: 6250
# 画像の形状: (225, 225, 3)
# 正解ラベル: ベーシック

# %%
# !pip install japanize_matplotlib

import cv2
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import japanize_matplotlib  # 日本語フォントのサポート
import torch.nn as nn
import torch.nn.functional as F
from torch import optim

def load_and_preprocess_images(base_path, label, num):
    """画像を読み込み、ラベルを付ける"""
    data = []
    img_dir = base_path  # base_pathを使用
    file_names = list_df[num]['file_name']  # 各ファイル名のリストを取得

    for file_name in file_names:
        img_path = os.path.join(img_dir, file_name)  # OSに依存しないファイルパス作成
        img = cv2.imread(img_path)
        if img is None:
            print(f"画像が読み込めませんでした: {img_path}")
            continue
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # BGRからRGBに変換
        data.append((img_rgb, label))  # 修正: 画像全体とラベルを対応付ける

    return data

def data_info(df):
    """データフレームからラベルとベースパスを取得"""
    label = df['ancestry'].unique()[0]
    base_path = '/content/drive/MyDrive/PythonProjects/トレンド予測/服の検出/imgs/{}'.format(label)
    return label, base_path

# 系統名のリスト
style_names = [
    'ベーシック',
    'アメリカンカジュアル（アメカジ）',
    'モードカジュアル',
    'スポーツカジュアル',
    'ストリートカジュアル',
    'アウトドア',
    'エレガンス',
    'ガーリー',
    'オフィスカジュアル',
    'キャリア',
    'マニッシュ',
    'デザイナーズ',
    'トラッド',
    'ノームコア',
    'ナチュラル',
    '韓国（オルチャン）',
    '量産型',
    '地雷系'
]

# ラベルと画像パスのリストを作成
list_labels = []
list_paths = []
for i in range(len(sum_list)):
    label, base_path = data_info(list_df[i])
    list_labels.append(label)
    list_paths.append(base_path)

# データの読み込みと前処理
list_data2 = []
for i, style in enumerate(sum_list):
    if i >= len(list_paths) or i >= len(list_labels):
        print(f"インデックス {i} が list_paths または list_labels の範囲外です")
        continue
    data = load_and_preprocess_images(list_paths[i], list_labels[i], i)
    list_data2.append(data)

# データを特徴量とラベルに分ける
X = []
y = []

for data in list_data2:
    for img, label in data:
        X.append(img)
        y.append(label)

X = np.array(X)

# 系統名を数値に変換するための辞書を作成
label_to_index = {name: idx for idx, name in enumerate(style_names)}

# ラベルを数値に変換
y = np.array([label_to_index[lbl] for lbl in y])

# データセットのカスタムクラス
class ImageDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

# データセットとデータローダーの作成
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((32, 32)),  # CIFAR-10に合わせたリサイズ
    transforms.RandomAffine([-15, 15], scale=(0.8, 1.2)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

dataset = ImageDataset(images=X, labels=y, transform=transform)
train_loader = DataLoader(dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(dataset, batch_size=len(dataset), shuffle=False)

# データ可視化
n_image = 25
dataiter = iter(train_loader)
images, labels = next(dataiter)

plt.figure(figsize=(10,10))
for i in range(n_image):
    plt.subplot(5, 5, i+1)
    plt.imshow(np.transpose(images[i].numpy(), (1, 2, 0)))
    plt.title(style_names[labels[i].item()])  # 系統名でラベルを取得
    plt.tick_params(labelbottom=False, labelleft=False, bottom=False, left=False)

plt.show()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 37.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for japanize_matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=46f195a616529c0c87edffa832ffda2a217911d3d59852e20adb0df04439c4a2
#   Stored in directory: /root/.cache/pip/wheels/61/7a/6b/df1f79be9c59862525070e157e62b08eab8ece27c1b68fbb94
# Successfully built japanize_matplotlib
# ...
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
# import torch.nn as nn
# import torch.nn.functional as F

# class FCNNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.conv1 = nn.Conv2d(3, 6, 5)  # 畳み込み層
#         self.pool = nn.MaxPool2d(2, 2)  # プーリング層
#         self.conv2 = nn.Conv2d(6, 16, 5)  # 畳み込み層
#         self.conv3 = nn.Conv2d(16, 256, 1)  # 1x1畳み込み層でチャンネル数を増やす
#         self.conv4 = nn.Conv2d(256, 10, 1)  # 1x1畳み込み層でクラス数に対応

#     def forward(self, x):
#         x = self.pool(F.relu(self.conv1(x)))  # プーリングと活性化
#         x = self.pool(F.relu(self.conv2(x)))  # プーリングと活性化
#         x = F.relu(self.conv3(x))  # 1x1畳み込みでチャンネル数を256に
#         x = self.conv4(x)  # クラス数に変換
#         x = F.adaptive_avg_pool2d(x, (1, 1))  # 全結合の代わりにGlobal Average Pooling
#         x = x.view(-1, 10)  # 出力を平坦化してクラスに対応
#         return x

# net = FCNNet()
# print(net)


# # 学習設定
# loss_fnc = nn.CrossEntropyLoss()
# optimizer = optim.Adam(net.parameters())

# # 学習と評価
# record_loss_train = []
# record_loss_test = []

# x_test, t_test = next(iter(test_loader))

# import torch
# import numpy as np
# from sklearn.metrics import precision_score, recall_score, f1_score

# def evaluate_model(model, data_loader):
#     model.eval()  # 評価モード
#     all_preds = []
#     all_targets = []

#     with torch.no_grad():
#         for x, t in data_loader:
#             y = model(x)
#             preds = y.argmax(1).cpu().numpy()  # 予測クラス
#             targets = t.cpu().numpy()  # 正解ラベル

#             all_preds.extend(preds)
#             all_targets.extend(targets)

#     # 評価指標の計算
#     accuracy = np.mean(np.array(all_preds) == np.array(all_targets)) * 100
#     precision = precision_score(all_targets, all_preds, average='weighted')
#     recall = recall_score(all_targets, all_preds, average='weighted')
#     f1 = f1_score(all_targets, all_preds, average='weighted')

#     return accuracy, precision, recall, f1

# # 学習ループ後に評価を行う
# for epoch in range(500):
#     net.train()
#     loss_train = 0
#     for batch_idx, (x, t) in enumerate(train_loader):
#         x, t = x, t
#         y = net(x)

#         # 正解ラベルの次元調整
#         if t.dim() == 1:  # [batch_size] の場合
#             loss = loss_fnc(y, t)
#         else:  # 他の形状の場合（通常は無いはず）
#             raise ValueError("Unexpected shape for target labels.")

#         loss_train += loss.item()
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()

#     # 評価
#     accuracy, precision, recall, f1 = evaluate_model(net, test_loader)
#     print(f"Epoch: {epoch+1}, Loss_Train: {loss_train:.4f}, Accuracy: {accuracy:.2f}%, Precision: {precision:.4f}, Recall: {recall:.4f}, F1: {f1:.4f}")

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# import torch.optim as optim
# from sklearn.metrics import precision_score, recall_score, f1_score
# import numpy as np

# class FCNNet(nn.Module):
#     def __init__(self, num_classes=12):  # 必要なクラス数を指定
#         super(FCNNet, self).__init__()
#         self.num_classes = num_classes  # num_classesをクラスの属性として保存
#         self.conv1 = nn.Conv2d(3, 6, 5)  # 畳み込み層
#         self.pool = nn.MaxPool2d(2, 2)  # プーリング層
#         self.conv2 = nn.Conv2d(6, 16, 5)  # 畳み込み層
#         self.conv3 = nn.Conv2d(16, 256, 1)  # 1x1畳み込み層でチャンネル数を増やす
#         self.conv4 = nn.Conv2d(256, num_classes, 1)  # 1x1畳み込み層でクラス数に対応

#     def forward(self, x):
#         x = self.pool(F.relu(self.conv1(x)))  # プーリングと活性化
#         x = self.pool(F.relu(self.conv2(x)))  # プーリングと活性化
#         x = F.relu(self.conv3(x))  # 1x1畳み込みでチャンネル数を256に
#         x = self.conv4(x)  # クラス数に変換
#         x = F.adaptive_avg_pool2d(x, (1, 1))  # 全結合の代わりにGlobal Average Pooling
#         x = x.view(-1, self.num_classes)  # クラス数に対応して出力を平坦化
#         return x

# # デバイス設定
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# # クラス数をデータセットに合わせて設定
# net = FCNNet(num_classes=18).to(device)
# print(net)

# # 学習設定
# loss_fnc = nn.CrossEntropyLoss()
# optimizer = optim.Adam(net.parameters())

# # 学習と評価
# record_loss_train = []
# record_loss_test = []

# def evaluate_model(model, data_loader):
#     model.eval()  # 評価モード
#     all_preds = []
#     all_targets = []

#     with torch.no_grad():
#         for x, t in data_loader:
#             x = x.to(device)
#             t = t.to(device)
#             y = model(x)
#             preds = y.argmax(1).cpu().numpy()  # 予測クラス
#             targets = t.cpu().numpy()  # 正解ラベル

#             all_preds.extend(preds)
#             all_targets.extend(targets)

#     # 評価指標の計算
#     accuracy = np.mean(np.array(all_preds) == np.array(all_targets)) * 100
#     precision = precision_score(all_targets, all_preds, average='weighted')
#     recall = recall_score(all_targets, all_preds, average='weighted')
#     f1 = f1_score(all_targets, all_preds, average='weighted')

#     return accuracy, precision, recall, f1

# # 学習ループ後に評価を行う
# for epoch in range(500):
#     net.train()
#     loss_train = 0
#     for batch_idx, (x, t) in enumerate(train_loader):
#         x, t = x.to(device), t.to(device)
#         y = net(x)

#         t = t.long()  # ラベルを整数型に変換
#         if t.dim() == 1:  # [batch_size] の場合
#             loss = loss_fnc(y, t)
#         else:  # 他の形状の場合（通常は無いはず）
#             raise ValueError("Unexpected shape for target labels.")

#         loss_train += loss.item()
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()

#     # 評価
#     accuracy, precision, recall, f1 = evaluate_model(net, test_loader)
#     print(f"Epoch: {epoch+1}, Loss_Train: {loss_train:.4f}, Accuracy: {accuracy:.2f}%, Precision: {precision:.4f}, Recall: {recall:.4f}, F1: {f1:.4f}")

# %%
# #モデルを保存
# import torch

# # モデルの学習済みパラメータを保存
# torch.save(net.state_dict(), '/content/drive/MyDrive/PythonProjects/トレンド予測/model.pth')

# print("モデルが保存されました")

# %%
# # モデルのインスタンス化と重みのロード（クラス数18に設定）
# net = FCNNet(num_classes=18).to(device)
# net.load_state_dict(torch.load('/content/drive/MyDrive/PythonProjects/トレンド予測/model.pth'))
# net.eval()  # 評価モードに設定

# print("モデルがロードされ、評価モードに設定されました")

# %%
# # 評価用関数（例）
# def evaluate_model(model, data_loader):
#     model.eval()  # 評価モード
#     all_preds = []
#     all_targets = []

#     with torch.no_grad():
#         for x, t in data_loader:
#             x = x.to(device)
#             t = t.to(device)
#             y = model(x)
#             preds = y.argmax(1).cpu().numpy()  # 予測クラス
#             targets = t.cpu().numpy()  # 正解ラベル

#             all_preds.extend(preds)
#             all_targets.extend(targets)

#     # 評価指標の計算（必要に応じて計算する指標を変更）
#     accuracy = np.mean(np.array(all_preds) == np.array(all_targets)) * 100
#     precision = precision_score(all_targets, all_preds, average='weighted')
#     recall = recall_score(all_targets, all_preds, average='weighted')
#     f1 = f1_score(all_targets, all_preds, average='weighted')

#     return accuracy, precision, recall, f1

# # テストデータの評価
# accuracy, precision, recall, f1 = evaluate_model(net, test_loader)
# print(f"Accuracy: {accuracy:.2f}%, Precision: {precision:.4f}, Recall: {recall:.4f}, F1: {f1:.4f}")

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# import torch

# # デバイスの設定
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# # データ可視化
# n_image = 25
# dataiter = iter(test_loader)
# images, labels = next(dataiter)

# # モデルを評価モードに設定
# net.eval()

# # 画像をモデルに通して予測を取得
# with torch.no_grad():
#     images = images.to(device)
#     outputs = net(images)
#     _, predicted = torch.max(outputs, 1)

# # 画像をCPUに戻して可視化
# images = images.cpu()

# plt.figure(figsize=(10,10))
# for i in range(n_image):
#     plt.subplot(5, 5, i+1)
#     plt.imshow(np.transpose(images[i].numpy(), (1, 2, 0)))
#     plt.title(f"Pred: {predicted[i].item()}")
#     plt.tick_params(labelbottom=False, labelleft=False, bottom=False, left=False)

# plt.show()

# %%
import torch
import torch.optim as optim
import torch.nn as nn
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np

# 系統名のリスト（修正済み）
style_names = [
    'ベーシック',
    'アメリカンカジュアル（アメカジ）',
    'モードカジュアル',
    'スポーツカジュアル',
    'ストリートカジュアル',
    'アウトドア',
    'エレガンス',
    'ガーリー',
    'オフィスカジュアル',
    'キャリア',
    'マニッシュ',
    'デザイナーズ',
    'トラッド',
    'ノームコア',
    'ナチュラル',
    '韓国（オルチャン）',
    '量産型',
    '地雷系'
]

class FCNNet(nn.Module):
    def __init__(self, num_classes=18):  # 必要なクラス数を指定
        super(FCNNet, self).__init__()
        self.num_classes = num_classes  # num_classesをクラスの属性として保存
        self.conv1 = nn.Conv2d(3, 6, 5)  # 畳み込み層
        self.pool = nn.MaxPool2d(2, 2)  # プーリング層
        self.conv2 = nn.Conv2d(6, 16, 5)  # 畳み込み層
        self.conv3 = nn.Conv2d(16, 256, 1)  # 1x1畳み込み層でチャンネル数を増やす
        self.conv4 = nn.Conv2d(256, num_classes, 1)  # 1x1畳み込み層でクラス数に対応

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))  # プーリングと活性化
        x = self.pool(F.relu(self.conv2(x)))  # プーリングと活性化
        x = F.relu(self.conv3(x))  # 1x1畳み込みでチャンネル数を256に
        x = self.conv4(x)  # クラス数に変換
        x = F.adaptive_avg_pool2d(x, (1, 1))  # 全結合の代わりにGlobal Average Pooling
        x = x.view(-1, self.num_classes)  # クラス数に対応して出力を平坦化
        return x

# デバイス設定
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# クラス数をデータセットに合わせて設定
net = FCNNet(num_classes=18).to(device)
print(net)

# 保存したモデルのパラメータをロード
net.load_state_dict(torch.load('/content/drive/MyDrive/PythonProjects/トレンド予測/model.pth'))

# モデルをトレーニングモードに設定（必要に応じて）
net.train()

# 損失関数と最適化手法を設定
criterion = nn.CrossEntropyLoss()  # 例: クロスエントロピー損失
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)  # 例: SGD最適化

# データローダーを設定（データセットの準備が必要）
# 例:
# train_loader = torch.utils.data.DataLoader(dataset, batch_size=64, shuffle=True)

# 学習設定
loss_fnc = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters())

# 学習と評価
record_loss_train = []
record_loss_test = []

def evaluate_model(model, data_loader):
    model.eval()  # 評価モード
    all_preds = []
    all_targets = []

    with torch.no_grad():
        for x, t in data_loader:
            x = x.to(device)
            t = t.to(device)
            y = model(x)
            preds = y.argmax(1).cpu().numpy()  # 予測クラス
            targets = t.cpu().numpy()  # 正解ラベル

            all_preds.extend(preds)
            all_targets.extend(targets)

    # 評価指標の計算
    accuracy = np.mean(np.array(all_preds) == np.array(all_targets)) * 100
    precision = precision_score(all_targets, all_preds, average='weighted')
    recall = recall_score(all_targets, all_preds, average='weighted')
    f1 = f1_score(all_targets, all_preds, average='weighted')

    return accuracy, precision, recall, f1

# 学習ループ後に評価を行う
for epoch in range(778):
    net.train()
    loss_train = 0
    for batch_idx, (x, t) in enumerate(train_loader):
        x, t = x.to(device), t.to(device)
        y = net(x)

        t = t.long()  # ラベルを整数型に変換
        if t.dim() == 1:  # [batch_size] の場合
            loss = loss_fnc(y, t)
        else:  # 他の形状の場合（通常は無いはず）
            raise ValueError("Unexpected shape for target labels.")

        loss_train += loss.item()
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # 評価
    accuracy, precision, recall, f1 = evaluate_model(net, test_loader)
    print(f"Epoch: {epoch+1}, Loss_Train: {loss_train:.4f}, Accuracy: {accuracy:.2f}%, Precision: {precision:.4f}, Recall: {recall:.4f}, F1: {f1:.4f}")
# Out:
# FCNNet(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (conv3): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#   (conv4): Conv2d(256, 18, kernel_size=(1, 1), stride=(1, 1))
# )
# Epoch: 1, Loss_Train: 182.6218, Accuracy: 40.32%, Precision: 0.4059, Recall: 0.4032, F1: 0.3987
# Epoch: 2, Loss_Train: 180.5174, Accuracy: 39.58%, Precision: 0.4119, Recall: 0.3958, F1: 0.3940
# Epoch: 3, Loss_Train: 181.4776, Accuracy: 39.58%, Precision: 0.4213, Recall: 0.3958, F1: 0.3956
# Epoch: 4, Loss_Train: 180.0307, Accuracy: 40.18%, Precision: 0.4194, Recall: 0.4018, F1: 0.3975
# Epoch: 5, Loss_Train: 179.9154, Accuracy: 40.22%, Precision: 0.4188, Recall: 0.4022, F1: 0.3945
# Epoch: 6, Loss_Train: 179.0979, Accuracy: 40.40%, Precision: 0.4129, Recall: 0.4040, F1: 0.3973
# ...

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# import torch.optim as optim
# from sklearn.metrics import precision_score, recall_score, f1_score
# import numpy as np

# # 系統名のリスト（修正済み）
# style_names = [
#     'ベーシック',
#     'アメリカンカジュアル（アメカジ）',
#     'モードカジュアル',
#     'スポーツカジュアル',
#     'ストリートカジュアル',
#     'アウトドア',
#     'エレガンス',
#     'ガーリー',
#     'オフィスカジュアル',
#     'キャリア',
#     'マニッシュ',
#     'デザイナーズ',
#     'トラッド',
#     'ノームコア',
#     'ナチュラル',
#     '韓国（オルチャン）',
#     '量産型',
#     '地雷系'
# ]

# class FCNNet(nn.Module):
#     def __init__(self, num_classes=18):  # 必要なクラス数を指定
#         super(FCNNet, self).__init__()
#         self.num_classes = num_classes  # num_classesをクラスの属性として保存
#         self.conv1 = nn.Conv2d(3, 6, 5)  # 畳み込み層
#         self.pool = nn.MaxPool2d(2, 2)  # プーリング層
#         self.conv2 = nn.Conv2d(6, 16, 5)  # 畳み込み層
#         self.conv3 = nn.Conv2d(16, 256, 1)  # 1x1畳み込み層でチャンネル数を増やす
#         self.conv4 = nn.Conv2d(256, num_classes, 1)  # 1x1畳み込み層でクラス数に対応

#     def forward(self, x):
#         x = self.pool(F.relu(self.conv1(x)))  # プーリングと活性化
#         x = self.pool(F.relu(self.conv2(x)))  # プーリングと活性化
#         x = F.relu(self.conv3(x))  # 1x1畳み込みでチャンネル数を256に
#         x = self.conv4(x)  # クラス数に変換
#         x = F.adaptive_avg_pool2d(x, (1, 1))  # 全結合の代わりにGlobal Average Pooling
#         x = x.view(-1, self.num_classes)  # クラス数に対応して出力を平坦化
#         return x

# # デバイス設定
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# # クラス数をデータセットに合わせて設定
# net = FCNNet(num_classes=18).to(device)
# print(net)

# # 学習設定
# loss_fnc = nn.CrossEntropyLoss()
# optimizer = optim.Adam(net.parameters())

# # 学習と評価
# record_loss_train = []
# record_loss_test = []

# def evaluate_model(model, data_loader):
#     model.eval()  # 評価モード
#     all_preds = []
#     all_targets = []

#     with torch.no_grad():
#         for x, t in data_loader:
#             x = x.to(device)
#             t = t.to(device)
#             y = model(x)
#             preds = y.argmax(1).cpu().numpy()  # 予測クラス
#             targets = t.cpu().numpy()  # 正解ラベル

#             all_preds.extend(preds)
#             all_targets.extend(targets)

#     # 評価指標の計算
#     accuracy = np.mean(np.array(all_preds) == np.array(all_targets)) * 100
#     precision = precision_score(all_targets, all_preds, average='weighted')
#     recall = recall_score(all_targets, all_preds, average='weighted')
#     f1 = f1_score(all_targets, all_preds, average='weighted')

#     return accuracy, precision, recall, f1

# # 学習ループ後に評価を行う
# for epoch in range(778):
#     net.train()
#     loss_train = 0
#     for batch_idx, (x, t) in enumerate(train_loader):
#         x, t = x.to(device), t.to(device)
#         y = net(x)

#         t = t.long()  # ラベルを整数型に変換
#         if t.dim() == 1:  # [batch_size] の場合
#             loss = loss_fnc(y, t)
#         else:  # 他の形状の場合（通常は無いはず）
#             raise ValueError("Unexpected shape for target labels.")

#         loss_train += loss.item()
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()

#     # 評価
#     accuracy, precision, recall, f1 = evaluate_model(net, test_loader)
#     print(f"Epoch: {epoch+1}, Loss_Train: {loss_train:.4f}, Accuracy: {accuracy:.2f}%, Precision: {precision:.4f}, Recall: {recall:.4f}, F1: {f1:.4f}")

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

# デバイスの設定
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# データ可視化
n_image = 25
dataiter = iter(test_loader)
images, labels = next(dataiter)

# モデルを評価モードに設定
net.eval()

# 画像をモデルに通して予測を取得
with torch.no_grad():
    images = images.to(device)
    outputs = net(images)
    _, predicted = torch.max(outputs, 1)

# 画像をCPUに戻して可視化
images = images.cpu()

# 系統名のリスト（修正済み）
style_names = [
    'ベーシック',
    'アメリカンカジュアル（アメカジ）',
    'モードカジュアル',
    'スポーツカジュアル',
    'ストリートカジュアル',
    'アウトドア',
    'エレガンス',
    'ガーリー',
    'オフィスカジュアル',
    'キャリア',
    'マニッシュ',
    'デザイナーズ',
    'トラッド',
    'ノームコア',
    'ナチュラル',
    '韓国（オルチャン）',
    '量産型',
    '地雷系'
]

plt.figure(figsize=(10,10))
for i in range(n_image):
    plt.subplot(5, 5, i+1)
    plt.imshow(np.transpose(images[i].numpy(), (1, 2, 0)))
    plt.title(f"Pred: {style_names[predicted[i].item()]}")
    plt.tick_params(labelbottom=False, labelleft=False, bottom=False, left=False)

plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
# モデルのインスタンス化と重みのロード（クラス数18に設定）
net = FCNNet(num_classes=18).to(device)
net.load_state_dict(torch.load('/content/drive/MyDrive/PythonProjects/トレンド予測/model.pth'))
net.eval()  # 評価モードに設定

print("モデルがロードされ、評価モードに設定されました")


# 評価用関数（例）
def evaluate_model(model, data_loader):
    model.eval()  # 評価モード
    all_preds = []
    all_targets = []

    with torch.no_grad():
        for x, t in data_loader:
            x = x.to(device)
            t = t.to(device)
            y = model(x)
            preds = y.argmax(1).cpu().numpy()  # 予測クラス
            targets = t.cpu().numpy()  # 正解ラベル

            all_preds.extend(preds)
            all_targets.extend(targets)

    # 評価指標の計算（必要に応じて計算する指標を変更）
    accuracy = np.mean(np.array(all_preds) == np.array(all_targets)) * 100
    precision = precision_score(all_targets, all_preds, average='weighted')
    recall = recall_score(all_targets, all_preds, average='weighted')
    f1 = f1_score(all_targets, all_preds, average='weighted')

    return accuracy, precision, recall, f1

# テストデータの評価
accuracy, precision, recall, f1 = evaluate_model(net, test_loader)
print(f"Accuracy: {accuracy:.2f}%, Precision: {precision:.4f}, Recall: {recall:.4f}, F1: {f1:.4f}")
# Out:
# モデルがロードされ、評価モードに設定されました
# Accuracy: 39.84%, Precision: 0.4125, Recall: 0.3984, F1: 0.3912

# %%
#モデルを保存
import torch

# モデルの学習済みパラメータを保存
torch.save(net.state_dict(), '/content/drive/MyDrive/PythonProjects/トレンド予測/model.pth')

print("モデルが保存されました")
# Out:
# モデルが保存されました
